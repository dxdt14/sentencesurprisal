# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import time

# %%
#read the text file
file = open("Manual Sentence Rankings.txt", "r", encoding = "utf8")
file_data = file.read()
lines = file_data.splitlines()
file.close()

data = []

#only use senteces that contain the keyword
keyword = ""
for s in lines:
    if keyword in s:
        data.append(s)

#appending a random weird sentence to see if it pops to the top of the sentence rankings        
#data.append("Colorless green ideas sleep furiously .")
#data.append("Écriteau lumineux avec écrit pizza Kebab .")
data.append("Have a nice day !")

# %%
start = time.time()
IDF = TfidfVectorizer(lowercase=False)
result = IDF.fit_transform(data)
end = time.time()
print(end-start)
# Out:
# 0.0029761791229248047

# %%
idf_results = {}
for i, j in zip(IDF.get_feature_names_out(), IDF.idf_):
    idf_results[i] = j

# %%
# footballers_goals = {'Eusebio': 120, 'Cruyff': 104, 'Pele': 150, 'Ronaldo': 132, 'Messi': 125}

# sorted_footballers_by_goals = sorted(footballers_goals.items(), key=lambda x:x[1])
# print(sorted_footballers_by_goals)

# %%
sen_surprisals = []
temp = []
#print(data)
for i in data:
    for j in i.split():
        if not j in idf_results.keys():
            continue
        temp.append(idf_results[j])
    sen_surprisals.append(np.mean(temp))
    temp.clear()
print(sen_surprisals)
# Out:
# [4.044522437723423, 3.063467482035737, 3.145377686400659, 2.93464011777615, 3.295589369334925, 2.9195700201408563, 3.385413616489496, 3.11003673024816, 3.4292547078142284, 2.8866931057008536, 2.924838045923748, 3.3578291092772345, 3.5617279025828226, 2.942736277590372, 3.248070956819441, 3.1192406715963252, 3.3930511686361697, 3.179350029286039, 3.317584507560082, 3.3194976069757334, 3.131082617166424, 3.3901268334493655, 3.2964268973227164, 3.283189939769359, 3.087803259485354, 3.2301833513643565, 2.5466563009464274, 2.5466563009464274, 3.1151844363987493, 2.910789977169371, 2.7405147692473744, 2.5869419219022207, 2.6449169479738295, 2.942240321321674, 2.733812119417938, 3.0928568152808427, 3.0459450132054258, 2.843745024302115, 2.5466563009464274, 2.343923746892345, 3.7742123656513136]

# %%
dict_sen_surprisals = {}
for i in range(len(sen_surprisals)):
    dict_sen_surprisals[data[i]] = sen_surprisals[i]

# %%
sorted_idf_results = sorted(dict_sen_surprisals.items(), key= lambda x:x[1], reverse=True)
sorted_sentences = []
for i in sorted_idf_results:
    sorted_sentences.append(i[0])

# %%
print(sorted_sentences)
# Out:
# ['Colorless green ideas sleep furiously .', 'Have a nice day !', "as i mentioned it does n't look or taste quite like a traditional pizza .", 'received a phone call the following day asking about their service and pizza .', 'we decided on uno because pizza sounded good to us .', 'we ordered a large pizza here to go one night and were not disappointed .', 'i will be returning for my pizza fix again and again and again ...', 'it was just a step up , maybe two , from frozen pizza .', 'i just had a white pizza with added spinach .', 'my family decided to split a traditional pizza with pepperoni and mushroom .', 'we sat down , ordered a pizza and it was served within _num_ minutes .', 'thanks ny pizza express !', 'top _num_ pizza in pittsburgh .', 'excellent pizza - although the mushrooms were from a can .', 'just not a fan of onions on my pizza .', 'sadly , the pizza was sparsely topped with cheese and sausage .', 'this is the pizza i cut my first tooth on as a kid .', 'i ordered pizza from this location recently .', 'pizza by the slice are very large .', 'i had the spinoccoli deep dish pizza and i loved it !', 'the owner was nice enough about refunding the money for the pizza .', 'great pizza , great price !', 'my pizza still had onions in it .', 'The pizza is like a cat .', 'best pizza ever .', 'i tasted the pizza and the crust was undercooked and burnt on the edges .', 'excellent pizza and excellent wings .', 'second-degree burns notwithstanding , the pizza was tasty !', 'this is an old-school pizza shop !', 'square pizza is weird .', 'pizza sounded amazing .', 'the pizza place was very cozy .', 'but , this is great pizza .', 'got a large pizza .', 'the pizza is affordable and very tasty !', 'this pizza is a classic !', 'the large pizza is huge .', 'horrible pizza .', 'terrible pizza .', 'awesome pizza .', 'good pizza .']

# %%
with open("IDF Sentence_Rankings", 'w') as f:
    for i in sorted_sentences:
        f.write(i + "\n")
    f.close()

# %%
print(idf_results['green'])
# Out:
# 4.044522437723423

# %%
print(idf_results['Colorless'] + idf_results['green'] + idf_results['ideas'] + idf_results['sleep'] + idf_results['furiously'])
# Out:
# 20.222612188617113

# %%
print(data)
# Out:
# ['Colorless green ideas sleep furiously .', 'The pizza is like a cat .', 'this is the pizza i cut my first tooth on as a kid .', 'second-degree burns notwithstanding , the pizza was tasty !', 'thanks ny pizza express !', 'square pizza is weird .', 'i will be returning for my pizza fix again and again and again ...', 'the owner was nice enough about refunding the money for the pizza .', 'received a phone call the following day asking about their service and pizza .', 'the pizza place was very cozy .', 'this is an old-school pizza shop !', 'it was just a step up , maybe two , from frozen pizza .', "as i mentioned it does n't look or taste quite like a traditional pizza .", 'i tasted the pizza and the crust was undercooked and burnt on the edges .', 'excellent pizza - although the mushrooms were from a can .', 'pizza by the slice are very large .', 'we decided on uno because pizza sounded good to us .', 'sadly , the pizza was sparsely topped with cheese and sausage .', 'my family decided to split a traditional pizza with pepperoni and mushroom .', 'i just had a white pizza with added spinach .', 'i ordered pizza from this location recently .', 'we ordered a large pizza here to go one night and were not disappointed .', 'we sat down , ordered a pizza and it was served within _num_ minutes .', 'top _num_ pizza in pittsburgh .', 'my pizza still had onions in it .', 'just not a fan of onions on my pizza .', 'horrible pizza .', 'terrible pizza .', 'i had the spinoccoli deep dish pizza and i loved it !', 'pizza sounded amazing .', 'got a large pizza .', 'the large pizza is huge .', 'this pizza is a classic !', 'excellent pizza and excellent wings .', 'the pizza is affordable and very tasty !', 'great pizza , great price !', 'best pizza ever .', 'but , this is great pizza .', 'awesome pizza .', 'good pizza .', 'Have a nice day !']

# %%
print(np.where(np.array(sorted_sentences) == "Have a nice day !")[0][0])
# Out:
# 1

# %%
sorted_sentences[179135]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 sorted_sentences[179135]
#
# IndexError: list index out of range

# %%
print(sorted_idf_results)
# Out:
# [('Colorless green ideas sleep furiously .', 8.337842945051914), ('thus , allowing proper staffing .', 8.028532513856891), ('i read several reviews regarding unfriendly staffers/owners .', 7.715139883209841), ('horribly under staffed .', 7.068746569808883), ('-staff rude ( see explanation below )', 7.060732261129919), ('severely understaffed .', 6.966259938091724), ('right draft picks , right coaching staff changes everything .', 6.766475392393495), ('waiter disappeared for _num_ minutes to serve larger group due to staffing mismanagement .', 6.700904749395827), ('somewhat understaffed for lunchtime .', 6.695705318368616), ('staffing :', 6.684712911935851), ('first impressions : dark , confined , and understaffed .', 6.486492705377269), ("while slightly odd , lidia 's boasts a ridiculous number of service staff .", 6.447439453320901), ('i just sincerely hope they hire more competent waitstaff .', 6.446026127134235), ('never going here again unless they re-staff pronto ! !', 6.414024900294322), ('as an adventure seeker , overall i would suggest a nicer staff .', 6.295969244727679), ('most supercuts staff spend 12-15 mins .', 6.236387289248744), ('the er staff certainly does not mess around when someone presents with cardiac symptoms .', 6.223784432183528), ('best coffee , ultimate staff , neighborhood gem', 6.208924147548859), ('the staff explained everything ( including insurance coverage ) thoroughly .', 6.182502984128524), ('truffle fries to die for & unique delicious cocktails w/friendly staff to boot !', 6.16307787346038), ('credit card stolen by staff', 6.142957177196077), ('incredibly unfriendly staff , completely clueless consultant .', 6.138288439752799), ('waitstaff hassle you repeatedly to order desserts .', 6.12129788931029), ('we both dislike pubic displays that include singing and clapping by the waitstaff .', 6.120564204226136), ('cleaning staff leaves at _num_ pm , btw .', 6.119042849081517), ('another overdone steak and utterly inattentive staff !', 6.10354842947121), ('staffing and ticket times have been a recurring issues .', 6.027608475802934), ('took the staff elevator due to heavy conference intake .', 5.989585472121529), ('this staff needs some serious lessons in public relations and social skills .', 5.972355768019387), ('sloppier and sloppier decorating , ruder and ruder counter staff .', 5.942711034072857), ('waitstaff has a pretty poor knowledge of their own drink menu .', 5.938014540423767), ('they might need to look at their staffs qualifications ...', 5.909101384878868), ('untrained and understaffed bartenders will keep me from coming back .', 5.9031092685744495), ('the pharmacy seems to be staffed by high school interns .', 5.885588148035008), ('two thumbs up on sushi and sushi chef but two thumbs down on waitstaff', 5.8834743590224265), ('nothing erks me more then seeing idol wait staff and hungry patrons .', 5.882776493372192), ('lots of people running around like crazy and if your understaffed hire more people !', 5.812655315681477), ('large portion sizes , free refills on soda , and the friendliest staff around .', 5.790305133877646), ('for a sunday just after church , they were well enough staffed .', 5.780878948169982), ('the staff constantly bussed tables at an impressive speed .', 5.776425481788461), ("i do n't shop at stores that hire such terrible staff .", 5.770154777155736), ("then all the staff repeatedly said like a parrot `` call corporate '' .", 5.765240830131558), ('i have never been treated so rudely by a waitstaff before in my life .', 5.74350480317129), ('summary : beautiful hotel , highly error-prone staff .', 5.730672569960646), ('staff seems to be bumping into each other and lines quickly form .', 5.727597369537084), ('there do seem to be some staffing problems , though .', 5.713572101283114), ('friendly staff , same starbucks fair you get anywhere else .', 5.702241838583105), ('icy cold staff .', 5.698015211275926), ("it 's the customers fault your staff ca n't handle a sat ...
